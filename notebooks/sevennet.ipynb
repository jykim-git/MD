# %%
import sys
sys.path.append('../')

# %%
from preprocess.sevennet import structure_liflow

structure_liflow(device="cuda:0", data_dir="../../liflow_data/data/universal/")

# %%
from preprocess.sevennet import structure_obelix
structure_obelix(device="cuda:0", data_dir="../../obelix_data/")

# %%
from preprocess.sevennet import structure_amorphous_T

structure_amorphous_T(device="cuda:2", data_dir="../data/")
